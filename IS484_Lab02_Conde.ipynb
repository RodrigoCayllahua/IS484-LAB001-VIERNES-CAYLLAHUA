# %% [markdown]
# ## Representación de un problema mediante estados

# %% [markdown]
# **Parte A: Completar la ficha del problema para el siguiente caso:** un repartidor debe ir desde el Almacén hasta la Zona Norte, pudiendo pasar por distintos puntos intermedios de la ciudad.

# %% [markdown]
# | Estado | Descripción |
# | :--- | :--- |
# | **Estado inicial** | El repartidor se encuentra en el Almacén |
# | **Estado objetivo** | El repartidor ha llegado a la ZONA NORTE |
# | **Acciones posibles** | El repartidor se puede desplazar a cualquier punto que esté conectado a él |
# | **Costo de cada acción** | El costo de acción para los tramos va a ser el mismo |
#
# ---

# %% [markdown]
# **Parte B: Representar el mapa de la ciudad como un grafo en Python**

# %%
mapa = {
    "Almacen": ["Centro", "Terminal"],
    "Centro": ["Almacen", "ZonaNorte", "Mercado"],
    "Terminal": ["Almacen", "Mercado"],
    "Mercado": ["Centro", "Terminal", "ZonaNorte"],
    "ZonaNorte": ["Centro", "Mercado"],
}

print(mapa)
# Out:
# {'Almacen': ['Centro', 'Terminal'], 'Centro': ['Almacen', 'ZonaNorte', 'Mercado'], 'Terminal': ['Almacen', 'Mercado'], 'Mercado': ['Centro', 'Terminal', 'ZonaNorte'], 'ZonaNorte': ['Centro', 'Mercado']}

# %% [markdown]
# ## Implementación de BFS

# %% [markdown]
# **Búsqueda en amplitud para encontrar el camino más corto en el mapa**

# %%
def bfs(grafo, inicio, objetivo):
    # Inicializamos la cola con una lista que contiene el camino inicial: ['Almacen']
    cola = [[inicio]]
    
    # Creamos un conjunto (set) vacío para registrar los nodos visitados y evitar bucles
    visitados = set()
    
    # Bucle principal: se ejecuta mientras existan caminos pendientes en la cola
    while cola:
        # sacamos el primer camino ingresado (índice 0) para cumplir el orden FIFO (cola)
        camino = cola.pop(0)
        
        # Con [-1] tomamos el ÚLTIMO elemento de este camino (nuestra ubicación actual)
        nodo_actual = camino[-1]
        
        # Si la ubicación actual coincide con el destino final, retornamos el camino recorrido
        if nodo_actual == objetivo:
            return camino
            
        # Si el nodo actual no se ha visitado previamente, lo procesamos
        if nodo_actual not in visitados:
            visitados.add(nodo_actual)  # Marcamos el nodo como visitado
            
            # Recorremos cada nodo vecino conectado al nodo actual en el grafo
            for vecino in grafo[nodo_actual]:
                # Con el operador '+' unimos listas: creamos una nueva ruta extendida con el vecino
                nuevo_camino = camino + [vecino]
                
                # Agregamos la nueva ruta al final de la cola para evaluarla en los siguientes turnos
                cola.append(nuevo_camino)
                
    # Retornamos None si se revisaron todos los caminos posibles y no se halló ruta al objetivo
    return None

# Ejecutamos la función de búsqueda desde 'Almacen' hasta 'ZonaNorte'
resultado = bfs(mapa, "Almacen", "ZonaNorte")
print("Camino encontrado (BFS):", resultado)
# Out:
# Camino encontrado (BFS): ['Almacen', 'Centro', 'ZonaNorte']

# %% [markdown]
# ## Vectores y matrices con NumPy

# %% [markdown]
# **Parte A: Representar cuatro observaciones de un dataset simple** (por ejemplo, sensores de
# temperatura y humedad) como un vector cada una, y juntarlas en una matriz:

# %%
import numpy as np  # Importamos la librería NumPy para operaciones matriciales

# Definimos observaciones individuales como vectores 1D: [temperatura, humedad]
obs1 = np.array([22.5, 60])  # Registro 1
obs2 = np.array([19.0, 45])  # Registro 2
obs3 = np.array([25.3, 70])  # Registro 3
obs4 = np.array([21.0, 50])  # Registro 4

# Unimos los 4 vectores para estructurar una matriz 2D (Dataset)
dataset = np.array([obs1, obs2, obs3, obs4])

# Imprimimos la matriz completa y mostramos sus dimensiones (filas, columnas)
print("Dataset completo:")
print(dataset)
print("Forma de la matriz (filas, columnas):", dataset.shape)

# Seleccionamos la primera fila completa (índice 0) -> Observación 1
print("\nPrimera observación (fila 0):", dataset[0])

# Seleccionamos la primera columna completa con slicing [:, 0] -> Todas las temperaturas
print("Todas las temperaturas (columna 0):", dataset[:, 0])
# Out:
# Dataset completo:
# [[22.5 60. ]
#  [19.  45. ]
#  [25.3 70. ]
#  [21.  50. ]]
# Forma de la matriz (filas, columnas): (4, 2)
#
# Primera observación (fila 0): [22.5 60. ]
# Todas las temperaturas (columna 0): [22.5 19.  25.3 21. ]

# %% [markdown]
# ## Producto escalar y distancia euclidiana

# %% [markdown]
# **Parte A:** Calcular el producto escalar entre dos observaciones

# %%
# Calculamos el producto escalar entre la observación 1 y la observación 2
producto = np.dot(obs1, obs2)
print("Producto escalar entre obs1 y obs2:", producto)
# Out:
# Producto escalar entre obs1 y obs2: 3127.5

# %% [markdown]
# **Parte B:** Calcular la distancia euclidiana entre dos observaciones, primero con la fórmula manual
# y luego con NumPy

# %%
# Calculamos la distancia euclidiana paso a paso (resta, cuadrado, suma y raíz)
distancia_manual = np.sqrt(np.sum((obs1 - obs2) ** 2))
print("Distancia euclidiana (fórmula manual):", distancia_manual)

# Calculamos la misma distancia usando la función de norma vectorial de NumPy
distancia_numpy = np.linalg.norm(obs1 - obs2)
print("Distancia euclidiana (función NumPy):", distancia_numpy)
# Out:
# Distancia euclidiana (fórmula manual): 15.402921800749363
# Distancia euclidiana (función NumPy): 15.402921800749363

# %% [markdown]
# ## Ejercicio Práctico de Laboratorio

# %% [markdown]
# **Búsqueda en Profundidad (DFS)**

# %% [markdown]
# Se quiere encontrar, dentro de un conjunto de observaciones ya conocidas, cuál es la más parecida a
# una observación nueva  el mismo principio que usará el algoritmo KNN a partir de la Semana 7.

# %%
def dfs(grafo, inicio, objetivo):
    """Busca un camino entre 'inicio' y 'objetivo' usando DFS con una pila (LIFO)."""
    # 'pila' guarda las rutas por revisar; iniciamos con la ciudad de salida
    pila = [[inicio]]

    # 'visitados' es un conjunto vacio para evitar pasar dos veces por la misma ciudad
    visitados = set()

    # 'while' repite el proceso mientras existan rutas pendientes dentro de la pila
    while pila:
        # '.pop()' remueve y devuelve el ÚLTIMO camino de la pila (LIFO)
        camino = pila.pop()

        # '[-1]' extrae la ciudad donde nos encontramos en este momento
        nodo_actual = camino[-1]

        # 'if' evalua si alcanzamos el punto final
        if nodo_actual == objetivo:
            return camino  # 'return' devuelve la lista con el camino completo

        # 'if' revisa si la ciudad actual no ha sido marcada como visitada
        if nodo_actual not in visitados:
            # '.add()' registra la ciudad actual como visitada
            visitados.add(nodo_actual)

            # 'for' examina cada una de las ciudades vecinas conectadas
            for vecino in grafo[nodo_actual]:
                # Operador '+' genera una nueva ruta concatenando el vecino al camino previo
                nuevo_camino = camino + [vecino]

                # '.append()' agrega el nuevo camino al final de la pila
                pila.append(nuevo_camino)

    # 'return None' si la pila queda vacia y no existe ruta
    return None


# Ejecutamos el algoritmo DFS y mostramos el resultado
resultado_dfs = dfs(mapa, "Almacen", "ZonaNorte")
print("Camino encontrado (DFS):", resultado_dfs)
# Out:
# Camino encontrado (DFS): ['Almacen', 'Terminal', 'Mercado', 'ZonaNorte']

# %% [markdown]
# **Comparar el camino que encontró BFS (Sección 4.3) con el que encontró DFS: ¾son el mismo camino?
# ¾Cuál tiene menos pasos?**

# %% [markdown]
# **¿Son el mismo camino?**
# No, porque BFS explora las rutas por niveles (a lo ancho) mientras que DFS se va de frente por una sola rama hasta el fondo usando la pila, devolviendo un trayecto distinto.
#
# **¿Cuál tiene menos pasos?**
# BFS, porque al evaluar por niveles garantiza encontrar siempre la ruta más corta (con menos conexiones) en grafos sin pesos.

# %% [markdown]
# ## Vecino más cercano (KNN simplificado)

# %%
# Importamos la librería para evitar el error 'np is not defined'
import numpy as np

# Definimos la nueva observación a evaluar: [temperatura = 20.0, humedad = 52]
nueva_obs = np.array([20.0, 52])

# Lista para almacenar la distancia calculada hacia cada punto del dataset
distancias = []

# Recorremos cada fila del dataset guardado anteriormente
for obs in dataset:
    # Calculamos la distancia euclidiana entre la nueva observación y la fila actual
    dist = np.linalg.norm(nueva_obs - obs)

    # Guardamos el resultado dentro de la lista de distancias
    distancias.append(dist)

# Identificamos el índice de la distancia más pequeña
indice_cercano = np.argmin(distancias)

# Imprimimos los resultados
print("Distancias a cada fila del dataset:", distancias)
print(
    f"El vecino más cercano es la Fila {indice_cercano} con una distancia de {distancias[indice_cercano]:.2f}"
)
# Out:
# Distancias a cada fila del dataset: [np.float64(8.381527307120106), np.float64(7.0710678118654755), np.float64(18.76406139405859), np.float64(2.23606797749979)]
# El vecino más cercano es la Fila 3 con una distancia de 2.24
